# %%
import re
from io import StringIO
import pickle
import html
from html.parser import HTMLParser

# %%
class MLStripper(HTMLParser):
    def __init__(self):
        super().__init__()
        self.reset()
        self.strict = False
        self.convert_charrefs= True
        self.text = StringIO()
    def handle_data(self, d):
        self.text.write(d)
    def get_data(self):
        return self.text.getvalue()

def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()

# %%
with open("./seed_tweets_ent10m.txt", "rb") as fp:   
    seed_tweets_ent = pickle.load(fp)

# %%
print('Number of seed tweets: ' , len(seed_tweets_ent))
# Out:
# Number of seed tweets:  50000

# %% [markdown]
# # First 5000 non repetitive tweets after some cleanings

# %%
for i in seed_tweets_ent[0:5000]:
    temp = strip_tags(i)
    #temp = re.sub("“|”", '''"''', temp)  
    #temp = re.sub("’|′|‘|`", "'", temp)  
    temp = re.sub(r'[^\x00-\x7F]+|,Ä¶',' ', temp)  
    temp = temp.lower() 
    temp = re.sub(r'(http://|https://)\S+', '', temp) 
    temp = re.sub(r'www\.\S+', '', temp)
    temp = re.sub('( |^)@\S+', '', temp) 
    #temp= re.sub("[\"\+\-\|\*\?\(\)\/\\\^\[\]``<>\.{}`′’‘'_;•«»,@:~!\=%&]+", ' ',temp) 
    temp = temp.encode('utf8').decode('ISO-8859-1') # decode('ISO-8859-1') or decode('latin-1') or decode('windows-1252')
    print(temp)
    print('-------------')
# Out:
# have a team that will do your business as much as & more than you will do. build a great team.they will build a great company #entrepreneurs
# -------------
# rt how to market your business with little or no money- #marketing #entrepreneur
# -------------
# we need more #entrepreneurs who can create #businesses and #jobs.
# -------------
# #entrepreneur #business: is #marketing really only about selling products?  thanks
# -------------
# rt you don t need to build a business, you need to build people that support why you re in business.
# -------------
# "i don t have time to market my business." is that you? better do something about it. #marketing #sales #entrepreneur
# -------------
# 4 effective business models that built billion-dollar companies
# -------------
# business success comes with focus, why entrepreneurs need 'focus':  via
# -------------
# this entrepreneur built his business through social media (you can too)
# -------------
# ...
